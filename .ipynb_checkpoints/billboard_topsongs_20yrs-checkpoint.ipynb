# %%
pip install billboard.py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import json
import billboard
from time import sleep

#billboard.charts()

# %%
#Collect chart data from current week back to Jan 1, 2000

#Create empty list to store data collected
top100_data = []

chart_date = "2019-12-14"
top100_chart = billboard.ChartData('hot-100', chart_date)
counter = 100

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    #Allow for break in requests to server between weeks
    sleep(7)
    #Reset chart date to previous week and get corresponding chart
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', chart_date)
    
print(top100_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
# ...

# %%
chart_date = "2018-01-13"
top100_chart = billboard.ChartData('hot-100', chart_date)
counter = 100

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(7)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', chart_date)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2016-02-20"
top100_chart = billboard.ChartData('hot-100', chart_date)
counter = 100

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(7)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', chart_date)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2014-03-22"
top100_chart = billboard.ChartData('hot-100', chart_date)
counter = 100

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    #sleep(3)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', chart_date)
    
print(top100_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1381540478ad> in <module>
#       1 chart_date = "2014-03-22"
# ----> 2 top100_chart = billboard.ChartData('hot-100', chart_date)
#       3 counter = 100
#       4
#       5 for i in range (1, counter+1):
#
# NameError: name 'billboard' is not defined

# %%
chart_date = "2012-04-21"
top100_chart = billboard.ChartData('hot-100', chart_date)
counter = 25

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    #sleep(10)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', chart_date)
    
print(top100_data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-2eb9820ced07> in <module>
#      16     #sleep(10)
#      17     chart_date = top100_chart.previousDate
# ---> 18     top100_chart = billboard.ChartData('hot-100', chart_date)
#      19
#      20 print(top100_data)
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/billboard.py in __init__(self, name, date, fetch, timeout)
#     150         self.entries = []
#     151         if fetch:
# --> 152             self.fetchEntries()
#     153
#     154     def __repr__(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/billboard.py in fetchEntries(self)
#     372             message = "Chart not found (perhaps the name is misspelled?)"
#     373             raise BillboardNotFoundException(message)
# --> 374         req.raise_for_status()
#     375
# ...

# %%
chart_date = "2011-10-29"
top100_chart = billboard.ChartData('hot-100', chart_date)
counter = 25

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(10)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', chart_date)
    
print(top100_data)

# %%
chart_date = "2011-05-07"
top100_chart = billboard.ChartData('hot-100', chart_date)
counter = 26

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(5)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', chart_date)
    
print(top100_data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-bc0daaa19202> in <module>
#       1 chart_date = "2011-05-07"
# ----> 2 top100_chart = billboard.ChartData('hot-100', chart_date)
#       3 counter = 26
#       4
#       5 for i in range (1, counter+1):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/billboard.py in __init__(self, name, date, fetch, timeout)
#     150         self.entries = []
#     151         if fetch:
# --> 152             self.fetchEntries()
#     153
#     154     def __repr__(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/billboard.py in fetchEntries(self)
#     372             message = "Chart not found (perhaps the name is misspelled?)"
#     373             raise BillboardNotFoundException(message)
# --> 374         req.raise_for_status()
#     375
# ...

# %%
chart_date = "2010-11-06"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 26

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2010-05-08"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 26

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2009-11-07"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2008-11-08"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2007-11-10"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2006-11-11"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2005-11-12"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2004-11-13"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2003-11-15"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2002-11-16"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2001-11-17"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 52

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
chart_date = "2000-11-18"
top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
counter = 47

for i in range (1, counter+1):
    top_song = top100_chart[0]  # Get no. 1 song on chart
    title = top_song.title
    artist = top_song.artist
    weeks = top_song.weeks
        
    top100_data_dict = {"Chart Date": chart_date, "Title": title, "Artist": artist,
                        "Number of Weeks In Top 100": weeks}
    
    top100_data.append(top100_data_dict)
    
    sleep(8)
    chart_date = top100_chart.previousDate
    top100_chart = billboard.ChartData('hot-100', date=chart_date, timeout=1000)
    
print(top100_data)
# Out:
# [{'Chart Date': '2019-12-14', 'Title': 'Heartless', 'Artist': 'The Weeknd', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-12-07', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 13}, {'Chart Date': '2019-11-30', 'Title': 'Circles', 'Artist': 'Post Malone', 'Number of Weeks In Top 100': 12}, {'Chart Date': '2019-11-23', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 27}, {'Chart Date': '2019-11-16', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 26}, {'Chart Date': '2019-11-09', 'Title': 'Lose You To Love Me', 'Artist': 'Selena Gomez', 'Number of Weeks In Top 100': 2}, {'Chart Date': '2019-11-02', 'Title': 'Someone You Loved', 'Artist': 'Lewis Capaldi', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-26', 'Title': 'Truth Hurts', 'Artist': 'Lizzo', 'Number of Weeks In Top 100': 24}, {'Chart Date': '2019-10-19', 'Title': 'HIGHEST IN THE ROOM', 'Artist': 'Travis 
# ...

# %%
#Create dataframe from the list of dictionaries
top_songs_df = pd.DataFrame(top100_data)
top_songs_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ddb9f47f8d70> in <module>
#       1 #Create dataframe from the list of dictionaries
# ----> 2 top_songs_df = pd.DataFrame(top100_data)
#       3 top_songs_df.head()
#
# NameError: name 'top100_data' is not defined

# %%
top_songs_df = top_songs_df.set_index("Chart Date")
top_songs_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f98e7876f736> in <module>
# ----> 1 top_songs_df = top_songs_df.set_index("Chart Date")
#       2 top_songs_df.head()
#
# NameError: name 'top_songs_df' is not defined

# %%
#Save to csv
top_songs_df.to_csv("Resources/top_songs_20yrs.csv")
