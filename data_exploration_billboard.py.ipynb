# %%
pip install billboard.py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import billboard
import json
from datetime import timedelta

billboard.charts()
# Out:
# ['hot-100',
#  'billboard-200',
#  'artist-100',
#  'social-50',
#  'streaming-songs',
#  'radio-songs',
#  'digital-song-sales',
#  'on-demand-songs',
#  'top-album-sales',
#  'current-albums',
#  'catalog-albums',
#  'independent-albums',
#  'soundtracks',
#  'vinyl-albums',
#  'greatest-of-all-time-artists',
#  'greatest-billboard-200-albums',
#  'greatest-billboard-200-artists',
#  'greatest-hot-100-singles',
#  'greatest-hot-100-artists',
#  'greatest-hot-100-songs-by-women',
#  'greatest-hot-100-women-artists',
#  'greatest-billboard-200-albums-by-women',
#  'greatest-billboard-200-women-artists',
#  'greatest-billboards-top-songs-80s',
#  'greatest-billboards-top-songs-90s',
#  'greatest-of-all-time-pop-songs',
#  'greatest-of-all-time-pop-songs-artists',
#  'greatest-adult-pop-songs',
#  'greatest-adult-pop-artists',
#  'greatest-country-songs',
#  'greatest-country-albums',
#  'greatest-country-artists',
#  'greatest-hot-latin-songs',
#  'greatest-hot-latin-songs-artists',
# ...

# %%
start_date = "2000-01-01"
end_date = "2019-12-14"

date = str(start_date + timedelta(weeks=1))

top100_chart = billboard.ChartData('hot-100', date= date)
top_song = top100_chart[0]
top_song_name = top_song.name
top_song_artist = top_song.artist
top_song_weeks = top_song.weeks

top100_chart
# Out:
# Object `billboard.py` not found.

# %%
start_date = "2000-01-01"
end_date = 2019-12-14

date = start_date + str(timedelta(weeks=1))
print(date)
# Out:
# 2000-01-017 days, 0:00:00

# %%
song = chart[0]  # Get no. 1 song on chart

print(song.title)

print(song.artist)

print(song.weeks)  # Number of weeks on chart
# Out:
# Circles
# Post Malone
# 13

# %%
print(chart)
# Out:
# hot-100 chart from 2019-12-07
# -----------------------------
# 1. 'Circles' by Post Malone
# 2. 'Someone You Loved' by Lewis Capaldi
# 3. 'Good As Hell' by Lizzo
# 4. 'Memories' by Maroon 5
# 5. 'Roxanne' by Arizona Zervas
# 6. 'Lose You To Love Me' by Selena Gomez
# 7. 'Senorita' by Shawn Mendes & Camila Cabello
# 8. '10,000 Hours' by Dan + Shay & Justin Bieber
# 9. 'Truth Hurts' by Lizzo
# 10. 'No Guidance' by Chris Brown Featuring Drake
# 11. 'Dance Monkey' by Tones And I
# 12. 'BOP' by DaBaby
# 13. 'Panini' by Lil Nas X
# 14. 'Bad Guy' by Billie Eilish
# 15. 'HIGHEST IN THE ROOM' by Travis Scott
# 16. 'Ballin'' by Mustard Featuring Roddy Ricch
# 17. 'Trampoline' by SHAED
# 18. 'All I Want For Christmas Is You' by Mariah Carey
# 19. 'Lover' by Taylor Swift
# 20. 'Old Town Road' by Lil Nas X Featuring Billy Ray Cyrus
# 21. 'Hot' by Young Thug Featuring Gunna
# 22. 'One Man Band' by Old Dominion
# 23. 'Woah' by Lil Baby
# 24. 'Only Human' by Jonas Brothers
# ...
