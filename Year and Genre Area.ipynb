# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
all_df = pd.read_csv("Resources/track_audio_data_FINAL_FOREAL.csv").drop(columns=['Unnamed: 0']).drop_duplicates()
#all_df = pd.read_csv("Resources/track_audio_data_FINAL_FOREAL.csv")
all_df.head()
# Out:
#   Billboard Chart Date  Year  Month              Title         Artist  \
# 0           2019-12-14  2019     12          Heartless     The Weeknd
# 1           2019-12-07  2019     12            Circles    Post Malone
# 2           2019-11-30  2019     11            Circles    Post Malone
# 3           2019-11-23  2019     11  Someone You Loved  Lewis Capaldi
# 4           2019-11-16  2019     11  Someone You Loved  Lewis Capaldi
#
#          Genre         Spotify Song ID  Spotify Popularity Rating  \
# 0     R&B/Soul  57vxBYXtHMk6H1aD29V7PU                       94.0
# 1  Hip-Hop/Rap  21jGcNKet2qwijlDFuPiPb                       99.0
# 2  Hip-Hop/Rap  21jGcNKet2qwijlDFuPiPb                       99.0
# 3  Alternative  7qEHsqek33rTcFNT9PFqLf                       96.0
# 4  Alternative  7qEHsqek33rTcFNT9PFqLf                       96.0
#
#    Number of Weeks In Top 100  Danceability  ...  Mode  Speechiness  \
# 0                           2         0.531  ...   0.0       0.1110
# ...

# %%
#df = all_df.drop(['Unnamed: 0', 'Spotify Song ID'], axis=1)
#df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-3e0146877f6e> in <module>
# ----> 1 df = all_df.drop(['Unnamed: 0', 'Spotify Song ID'], axis=1)
#       2 df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df_year_genre = (all_df.groupby(['Year','Genre']).count())
df_year_genre.head(50)
# Out:
#                         Billboard Chart Date  Month  Title  Artist  \
# Year Genre
# 2000 Country                               2      2      2       2
#      Pop                                  15     15     15      15
#      Pop Latino                            3      3      3       3
#      R&B/Soul                              7      7      7       7
#      Rock                                 12     12     12      12
# 2001 Hip-Hop/Rap                           1      1      1       1
#      Pop                                   9      9      9       9
#      R&B/Soul                             26     26     26      26
#      Reggae                                1      1      1       1
#      Rock                                  4      4      4       4
#      Soundtrack                            5      5      5       5
# 2002 Hip-Hop/Rap                          29     29     29      29
#      Pop                                   2      2      2       2
# ...

# %%
df_y_g = df_year_genre.reset_index()
df_y_g.head(10)
# Out:
#    Year        Genre  Billboard Chart Date  Month  Title  Artist  \
# 0  2000      Country                     2      2      2       2
# 1  2000          Pop                    15     15     15      15
# 2  2000   Pop Latino                     3      3      3       3
# 3  2000     R&B/Soul                     7      7      7       7
# 4  2000         Rock                    12     12     12      12
# 5  2001  Hip-Hop/Rap                     1      1      1       1
# 6  2001          Pop                     9      9      9       9
# 7  2001     R&B/Soul                    26     26     26      26
# 8  2001       Reggae                     1      1      1       1
# 9  2001         Rock                     4      4      4       4
#
#    Spotify Song ID  Spotify Popularity Rating  Number of Weeks In Top 100  \
# 0                2                          2                           2
# 1               15                         15                          15
# ...

# %%
list(df_y_g.columns)
# Out:
# ['Year',
#  'Genre',
#  'Billboard Chart Date',
#  'Month',
#  'Title',
#  'Artist',
#  'Spotify Song ID',
#  'Spotify Popularity Rating',
#  'Number of Weeks In Top 100',
#  'Danceability',
#  'Energy',
#  'Key',
#  'Loudness',
#  'Mode',
#  'Speechiness',
#  'Acousticness',
#  'Instrumentalness',
#  'Liveness',
#  'Valence',
#  'Tempo',
#  'Explicitness',
#  'Duration (mins)',
#  'Time Signature']

# %%
#df = all_df.drop(['Unnamed: 0', 'Spotify Song ID'], axis=1)
#df.head()
df_yg_only = df_y_g.drop(['Title',
 'Artist',
 'Spotify Popularity Rating',
 'Number of Weeks In Top 100',
 'Danceability',
 'Energy',
 'Key',
 'Loudness',
 'Mode',
 'Acousticness',
 'Instrumentalness',
 'Liveness',
 'Valence',
 'Tempo',
 'Explicitness',
 'Duration (mins)',
 'Time Signature'], axis=1)

df_yg_only.head(50)
# Out:
#     Year              Genre  Billboard Chart Date  Month  Spotify Song ID  \
# 0   2000            Country                     2      2                2
# 1   2000                Pop                    15     15               15
# 2   2000         Pop Latino                     3      3                3
# 3   2000           R&B/Soul                     7      7                7
# 4   2000               Rock                    12     12               12
# 5   2001        Hip-Hop/Rap                     1      1                1
# 6   2001                Pop                     9      9                9
# 7   2001           R&B/Soul                    26     26               26
# 8   2001             Reggae                     1      1                1
# 9   2001               Rock                     4      4                4
# 10  2001         Soundtrack                     5      5                5
# 11  2002        Hip-Hop/Rap                    29     29               29
# ...

# %%
df_ygw = df_yg_only.rename(columns={'Billboard Chart Date': 'Weeks'})
df_ygw
# Out:
#     Year        Genre  Weeks  Month  Spotify Song ID  Speechiness
# 0   2000      Country      2      2                2            2
# 1   2000          Pop     15     15               15           15
# 2   2000   Pop Latino      3      3                3            3
# 3   2000     R&B/Soul      7      7                7            7
# 4   2000         Rock     12     12               12           12
# ..   ...          ...    ...    ...              ...          ...
# 80  2019      Country     19     19               19           19
# 81  2019  Hip-Hop/Rap      4      4                4            4
# 82  2019          Pop     19     19               19           19
# 83  2019     R&B/Soul      1      1                1            1
# 84  2019   Soundtrack      1      1                1            1
#
# [85 rows x 6 columns]

# %%
genres_list = df_ygw.Genre.unique()
genres_list
# Out:
# array(['Country', 'Pop', 'Pop Latino', 'R&B/Soul', 'Rock', 'Hip-Hop/Rap',
#        'Reggae', 'Soundtrack', 'Electronic', 'Alternative',
#        'Hardcore Rap', 'Rap', 'Singer/Songwriter', 'Dance', 'Pop/Rock'],
#       dtype=object)

# %%
df_ygw["Year"]= df_ygw["Year"].astype(str)
df_ygw.Year.unique()
# Out:
# array(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019'], dtype=object)

# %%
genres = df_ygw['Genre'].drop_duplicates()
margin_bottom = np.zeros(len(df['Year']))
#colors = ["#006D2C", "#31A354","#74C476"]
colors=cm.tab20c(np.linspace(0,1,len(genres)))

genres = df_ygw['Genre'].drop_duplicates()

pivot_df = df_ygw.pivot(index='Year', columns='Genre', values='Weeks')

myplot = pivot_df.plot.area(stacked=True, color=colors, figsize=(10,5)).legend(bbox_to_anchor=(1.24,1.017), loc='upper right')
plt.title('The "No.1 Genre" 2000 - 2019')
plt.ylabel('Weeks')

myfig = myplot.get_figure()

# %%
myfig.savefig('No1_Genre_2000-2019.png')

# %%
#plt.ylabel('Genre')
#plt.title('Genre from 2000-2019')
#plt.xticks(ind, ('2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       #'2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       #'2016', '2017', '2018', '2019'))
#years = range(20)
#country.head()
#plt.bar(years, rock)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-ac603bc4c442> in <module>
#       6 years = range(20)
#       7 country.head()
# ----> 8 plt.bar(years, rock)
#
# ~\Anaconda3\envs\PythonDataViz\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# ~\Anaconda3\envs\PythonDataViz\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
df_genre = df_yg_only[['Year','Genre','Billboard Chart Date']]
df_genre = df_genre.set_index('Year')
df_genre.head(30)

country = df_genre[df_genre['Genre'] == 'Country']['Billboard Chart Date']
rock = df_genre[df_genre['Genre'] == 'Rock']['Billboard Chart Date']

genre_d = {}

for g in genres_list:
    genre_d[g] = df_genre[df_genre['Genre'] == 'Country']['Billboard Chart Date']

print(genre_d['Country'])
# Out:
# Year
# 2000     2
# 2012     3
# 2019    19
# Name: Billboard Chart Date, dtype: int64
