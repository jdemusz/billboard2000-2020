# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
song_data = pd.read_csv("../Resources/track_audio_data_FINAL_FOREAL.csv").drop(columns=['Unnamed: 0']).drop_duplicates()
song_data.head()
# Out:
#   Billboard Chart Date  Year  Month              Title         Artist  \
# 0           2019-12-14  2019     12          Heartless     The Weeknd
# 1           2019-12-07  2019     12            Circles    Post Malone
# 2           2019-11-30  2019     11            Circles    Post Malone
# 3           2019-11-23  2019     11  Someone You Loved  Lewis Capaldi
# 4           2019-11-16  2019     11  Someone You Loved  Lewis Capaldi
#
#          Genre         Spotify Song ID  Spotify Popularity Rating  \
# 0     R&B/Soul  57vxBYXtHMk6H1aD29V7PU                       94.0
# 1  Hip-Hop/Rap  21jGcNKet2qwijlDFuPiPb                       99.0
# 2  Hip-Hop/Rap  21jGcNKet2qwijlDFuPiPb                       99.0
# 3  Alternative  7qEHsqek33rTcFNT9PFqLf                       96.0
# 4  Alternative  7qEHsqek33rTcFNT9PFqLf                       96.0
#
#    Number of Weeks In Top 100  Danceability  ...  Mode  Speechiness  \
# 0                           2         0.531  ...   0.0       0.1110
# ...

# %%
# song_data[song_data['Year']==2014].drop(columns=['Unnamed: 0']).drop_duplicates()

# %%
explicit_data = song_data[["Year", "Explicitness", "Billboard Chart Date"]].groupby(["Year", "Explicitness"]).count()
explicit_data = explicit_data.reset_index()
explicit_data
# Out:
#     Year  Explicitness  Billboard Chart Date
# 0   2000           0.0                    37
# 1   2000           1.0                     2
# 2   2001           0.0                    40
# 3   2001           1.0                     6
# 4   2002           0.0                    10
# 5   2002           1.0                    37
# 6   2003           0.0                    30
# 7   2003           1.0                    22
# 8   2004           0.0                    42
# 9   2004           1.0                    10
# 10  2005           0.0                    30
# 11  2005           1.0                    23
# 12  2006           0.0                    32
# 13  2006           1.0                    20
# 14  2007           0.0                    32
# 15  2007           1.0                    20
# 16  2008           0.0                    33
# 17  2008           1.0                    19
# 18  2009           0.0                    46
# 19  2009           1.0                     6
# ...

# %%
#####fig, ax = plot.subplots(figsize=(12, 8))
#####x = np.arange(len(explicit_data.Year.unique()))

# Define bar width. We'll use this to offset the second bar.
#####bar_width = 0.4

# Note we add the `width` parameter now which sets the width of each bar.
#####bar1 = ax.bar(x, explicit_data.loc[explicit_data['Explicitness'] == 1, 'Billboard Chart Date'],
            #width=bar_width)
# Same thing, but offset the x by the width of the bar.
#####bar2 = ax.bar(x + bar_width, explicit_data.loc[explicit_data['Explicitness'] == 0, 'Billboard Chart Date'],
            #width=bar_width)

# %%
plot.figure(figsize=(20,10))
sns.barplot(x="Year", y="Billboard Chart Date", hue="Explicitness", data=explicit_data)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
plot.savefig("explicitness_year.png")
